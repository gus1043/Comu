# %%
import requests

URL = 'https://dhlottery.co.kr/gameResult.do?method=byWin'
raw = requests.get(URL)

#print(raw) # 요청 성공 여부 출력
print(raw.text) # HTML 코드 출력
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="EUC-KR">
# <meta id="utitle" name="title" content="동행복권">
# <meta id="desc" name="description" content="동행복권 998회 당첨번호 13,17,18,20,42,45+41. 1등 총 12명, 1인당 당첨금액 2,076,499,657원.">
# <title>로또6/45 - 회차별 당첨번호</title>
# <title>동행복권</title>
#
#
#
#
#
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link rel="shortcut icon" href="/images/common/favicon.ico" type="image/x-icon">
# <link rel="icon" href="/images/common/favicon.ico" type="image/x-icon">
# <script type="text/javascript" src="/js/jquery-1.9.1.min.js"></script>
# <script type="text/javascript" src="/js/jquery-ui.js"></script>
# <script type="text/javascript" src="/js/common.js" charset="utf-8"></script>
# <script type="text/javascript">
#
# fn_g_init_message("");
#
# var gameUserId = "";
#
# function goGame(){
# 	var userId = "";
#
# 	if(userId == '' || userId == null){
# 		alert("로그인 후 사용 해주시기 바랍니다.");
# 		location.href = "/user.do?method=login";
# ...

# %%
import requests

URL = 'https://dhlottery.co.kr/gameResult.do?method=byWin'
raw = requests.get(URL)
target = '<div class="nums">'

if target in raw.text:
    idx = raw.text.index(target)
    print(raw.text[idx:idx + 578])
# Out:
# <Response [200]>

# %%
import requests

URL = 'https://www.hotelscombined.co.kr'
raw = requests.get(URL)
target = '<h3 class="cityName">'

print(raw)
print(raw.text)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="ko-kr" class="lt-ie11 lt-ie10 lt-ie9 lt-ie8 lt-ie7 Hotels-Search-Brands-Hotelscombined-HotelSearchPage-Html"> <![endif]-->
# <!--[if IE 7]> <html lang="ko-kr" class="lt-ie11 lt-ie10 lt-ie9 lt-ie8 Hotels-Search-Brands-Hotelscombined-HotelSearchPage-Html"> <![endif]-->
# <!--[if IE 8]> <html lang="ko-kr" class="lt-ie11 lt-ie10 lt-ie9 Hotels-Search-Brands-Hotelscombined-HotelSearchPage-Html"> <![endif]-->
# <!--[if IE 9]> <html lang="ko-kr" class="lt-ie11 lt-ie10 Hotels-Search-Brands-Hotelscombined-HotelSearchPage-Html"> <![endif]-->
# <!--[if IE 10]> <html lang="ko-kr" class="lt-ie11 Hotels-Search-Brands-Hotelscombined-HotelSearchPage-Html"> <![endif]-->
# <!--[if gt IE 9]><!--> <html lang="ko-kr" class=" Hotels-Search-Brands-Hotelscombined-HotelSearchPage-Html"> <!--<![endif]-->
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" >
# ...

# %%
import requests

URL = 'https://www.hotelscombined.co.kr'
raw = requests.get(URL)
target = '<h3 class="cityName">'

if target in raw.text:
    idx = raw.text.index(target)
    print(raw.text[idx:idx +10000000000])
# Out:
# <h3 class="cityName">부산</h3>
# <h4 class="locationName">대한민국</h4>
# </div>
# </a>
# </div>
# <div class="">
# <a class="_jfh _h-2 _iaA _jf5 _iax _iay _ibZ _iaz" href="/Place/Seoul.htm">
# <img
# src="/rimg/dimg/ff/d2/794e703d-city-35982-1620c5d9650.jpg?crop=true&width=190&height=240&xhint=1970&yhint=1348"
# class="_ixU"
# alt=""
# width="190"
# height="240"
# />
# <div class="_iU4 _ioK _SO _inV">
# <h3 class="cityName">서울</h3>
# <h4 class="locationName">대한민국</h4>
# </div>
# </a>
# </div>
# <div class="">
# <a class="_jfh _h-2 _iaA _jf5 _iax _iay _ibZ _iaz" href="/Place/Jeju.htm">
# <img
# src="/rimg/dimg/e1/4e/8ff30a1b-city-32610-17686cfdd47.jpg?crop=true&width=190&height=240&xhint=1504&yhint=751"
# class="_ixU"
# alt=""
# width="190"
# height="240"
# />
# <div class="_iU4 _ioK _SO _inV">
# <h3 class="cityName">제주시</h3>
# <h4 class="locationName">대한민국</h4>
# </div>
# </a>
# </div>
# <div class="">
# <a class="_jfh _h-2 _iaA _jf5 _iax _iay _ibZ _iaz" href="/Place/Seogwipo.htm">
# ...
